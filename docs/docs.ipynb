# %%
## Add to head before require <script src="https://cdnjs.cloudflare.com/ajax/libs/echarts/4.6.0/echarts.min.js"></script> 
using Namtso,DataFrames

# %%
points=1000
ec=EChart("scatter",rand(points),rand(points),title=Dict("text"=>"Double Scatter"))
series!(ec,"scatter",rand(points),rand(points),name="Green Series")
ec
# Out:
# EChart("Hv45f42q4L", Dict{String, Any}("xAxis" => Dict{Any, Any}[Dict("type" => "value")], "yAxis" => Dict{Any, Any}[Dict("type" => "value")], "title" => Dict{String, Any}("text" => "Double Scatter"), "series" => Any[Dict{String, Any}("name" => "Series1", "data" => Any[Any[0.16848815945466322, 0.8352837552620681], Any[0.961824136386519, 0.06527197787150119], Any[0.9816336890113287, 0.42331860321340864], Any[0.757175884255348, 0.8794866997601196], Any[0.6404762481559586, 0.8330874258061225], Any[0.7749779035904099, 0.20065956356293402], Any[0.35214368215661596, 0.43619683147059285], Any[0.1461545793641954, 0.2956439264353633], Any[0.3256397290010826, 0.7599518555321575], Any[0.4349198438136812, 0.355641881101465]  …  Any[0.9540773901449408, 0.9439787163726079], Any[0.6559237856919243, 0.06350159929836052], Any[0.769461731235805, 0.002401630295065682], Any[0.7983782554587024, 0.6727302213555381], Any[0.5261697532981794, 0.4781567030699744], Any[0.3516470662103047, 0.617769934480543], Any[0.4603331331858703, 0.17766598986551374], Any[0.5810453377239855, 0.33903092871978735], Any[0.12171693152311436, 0.5151245616880673], Any[0.7671671646346383, 0.9203424132256018]], "type" => "scatter"), Dict{String, Any}("name" => "Green Series", "data" => Any[Any[0.3338158748912561, 0.12321901613252839], Any[0.32365425796441216, 0.05755855788051689], Any[0.9014622583336828, 0.09135540346245863], Any[0.345339467100898, 0.07540614450479555], Any[0.9400186510172487, 0.4802671153979019], Any[0.1564556049203213, 0.24489961466678567], Any[0.3258890206374615, 0.6766298796880007], Any[0.7103223112069672, 0.8204794577643171], Any[0.3893853705092879, 0.9640829312403859], Any[0.4864337964169805, 0.34230280246082556]  …  Any[0.23229619290683368, 0.39666845814208296], Any[0.434746329816615, 0.5303051731018629], Any[0.6798156482796258, 0.14008668679422132], Any[0.6917613953010053, 0.2946627627714409], Any[0.11528183555177429, 0.34201735990793414], Any[0.5888745392151946, 0.9477797727521283], Any[0.773599336929208, 0.7186774660943384], Any[0.5639624763253989, 0.7376824230323665], Any[0.4920975563417198, 0.7141708444757651], Any[0.3469842564591973, 0.5042379220812018]], "type" => "scatter")], "legend" => Dict{String, Any}("data" => ["Series1", "Green Series"])), 800, 600)

# %%
ec=EChart("bar",["A","B","C","D","E"],[100,130,80,50,60])
series!(ec,"bar",["A","B","C","D","E"],[120,40,70,50,80])
series!(ec,"line",["A","B","C","D","E"],[50,110,60,20,70])
ec["title"]=Dict("text"=>"Multi Series")
ec
# Out:
# EChart("BBaROT6KKJ", Dict{String, Any}("xAxis" => Dict{Any, Any}[Dict("type" => "category")], "yAxis" => Dict{Any, Any}[Dict("type" => "value")], "title" => Dict("text" => "Multi Series"), "series" => Any[Dict{String, Any}("name" => "Series1", "data" => Any[Any["A", 100], Any["B", 130], Any["C", 80], Any["D", 50], Any["E", 60]], "type" => "bar"), Dict{String, Any}("name" => "Series2", "data" => Any[Any["A", 120], Any["B", 40], Any["C", 70], Any["D", 50], Any["E", 80]], "type" => "bar"), Dict{String, Any}("name" => "Series3", "data" => Any[Any["A", 50], Any["B", 110], Any["C", 60], Any["D", 20], Any["E", 70]], "type" => "line")], "legend" => Dict{String, Any}("data" => ["Series1", "Series2", "Series3"])), 800, 600)

# %%
df=DataFrame(A=rand(["A","B","C"],points),B=rand(points)*100,C=rand(points)*100)

EChart(df,title=Dict("text"=>"DataFrame Input"),series=[Dict("type"=>"scatter","name"=>"S1","encode"=>Dict("x"=>"B","y"=>"C","tooltip"=>["A","B"])),
        Dict("type"=>"scatter","name"=>"S2","encode"=>Dict("x"=>"C","y"=>"B"))])
# Out:
# EChart("bWKmW0AN2x", Dict{String, Any}("xAxis" => [Dict("type" => "value")], "yAxis" => [Dict("type" => "value")], "tooltip" => Dict{Any, Any}(), "title" => Dict("text" => "DataFrame Input"), "series" => Dict{String, Any}[Dict("name" => "S1", "encode" => Dict{String, Any}("tooltip" => ["A", "B"], "x" => "B", "y" => "C"), "type" => "scatter"), Dict("name" => "S2", "encode" => Dict("x" => "C", "y" => "B"), "type" => "scatter")], "dataset" => Dict{String, Any}("source" => Dict{String, Any}[Dict("B" => 17.11711593688482, "A" => "A", "C" => 63.07654095248743), Dict("B" => 55.12738348382249, "A" => "B", "C" => 37.12449285277317), Dict("B" => 29.537613994647515, "A" => "A", "C" => 34.4275286257824), Dict("B" => 21.17068767006829, "A" => "A", "C" => 38.08345191788914), Dict("B" => 54.457494408809325, "A" => "A", "C" => 16.432732380518566), Dict("B" => 71.84785011424879, "A" => "C", "C" => 86.10709458762813), Dict("B" => 27.89392348622335, "A" => "B", "C" => 82.86775096936067), Dict("B" => 20.30162375938214, "A" => "B", "C" => 30.172195966537917), Dict("B" => 0.7575398952362478, "A" => "B", "C" => 76.8878843109957), Dict("B" => 40.84658696024203, "A" => "A", "C" => 91.871215496879)  …  Dict("B" => 51.03622908772844, "A" => "B", "C" => 83.58772689491954), Dict("B" => 0.1823012742130925, "A" => "A", "C" => 77.21637430109978), Dict("B" => 38.209800155671246, "A" => "C", "C" => 26.633537795240848), Dict("B" => 26.08808417191576, "A" => "C", "C" => 50.61103831228978), Dict("B" => 55.036384149320426, "A" => "C", "C" => 97.3624354768449), Dict("B" => 59.07964070589161, "A" => "C", "C" => 80.56085560468723), Dict("B" => 48.2627609087508, "A" => "A", "C" => 61.601066752092294), Dict("B" => 19.080112199696618, "A" => "A", "C" => 40.76243317398105), Dict("B" => 6.481328618388204, "A" => "B", "C" => 4.556301222994907), Dict("B" => 78.25934781825637, "A" => "A", "C" => 7.004567281749264)], "dimensions" => ["A", "B", "C"]), "legend" => Dict{Any, Any}()), 800, 600)
