# %%
## Add to head before require <script src="https://cdnjs.cloudflare.com/ajax/libs/echarts/4.6.0/echarts.min.js"></script> 
using Namtso

# %%
points=1000
ec=EChart("scatter",rand(points),rand(points),title=Dict("text"=>"Double Scatter"))
series!(ec,"scatter",rand(points),rand(points),name="Blue Series")
ec
# Out:
# EChart("qbQBTjzg6X", Dict{String,Any}("xAxis" => Dict{Any,Any}[Dict("type" => "value")],"yAxis" => Dict{Any,Any}[Dict("type" => "value")],"title" => Dict("text" => "Double Scatter"),"series" => Any[Dict{String,Any}("name" => "Series1","data" => Any[Any[0.8587125401308486, 0.4915884833020119], Any[0.6681298645294838, 0.9507571387805946], Any[0.6995870024647373, 0.9418940169159042], Any[0.10960529828458188, 0.14714653004283273], Any[0.8695549577126811, 0.3613834471330297], Any[0.9538328873256361, 0.9761965292422157], Any[0.26110159233043806, 0.8903525218154378], Any[0.44363842251384833, 0.5920678707387652], Any[0.018633798837184967, 0.36120951991493455], Any[0.61815749127903, 0.0606350157560378]  …  Any[0.9757202978147608, 0.25759736332467553], Any[0.39519658678643377, 0.45661897548360675], Any[0.4894514303305597, 0.21707721373273126], Any[0.6874124631620266, 0.7657992574846177], Any[0.8803852253511542, 0.8208950974525746], Any[0.391927012930976, 0.7893819688994608], Any[0.7292764021816918, 0.9712761185011209], Any[0.21646208132494493, 0.535659767287952], Any[0.12207490339280236, 0.3434946669883321], Any[0.3107506546917238, 0.4717295831905579]],"type" => "scatter"), Dict{String,Any}("name" => "Blue Series","data" => Any[Any[0.9279074840560131, 0.44504352729801644], Any[0.07896970477886978, 0.3927673841357544], Any[0.8619574178770635, 0.1368940193635304], Any[0.14258164694330833, 0.0060892177378848444], Any[0.05751504507320204, 0.38358226512851146], Any[0.496497111666762, 0.5132034578310756], Any[0.1015893064012805, 0.618599853163478], Any[0.5927459567117834, 0.581390361053076], Any[0.11943370078538718, 0.43956666694090396], Any[0.14914180944168698, 0.4523327252944509]  …  Any[0.6241255898819216, 0.31604606876056174], Any[0.21995978977023212, 0.8740562568000572], Any[0.2949302293203493, 0.35716919307202355], Any[0.046145615753226066, 0.8765617626166533], Any[0.21065621593501582, 0.24042723576428982], Any[0.3191807514001963, 0.29021051603567405], Any[0.4410028476803547, 0.22932832327922803], Any[0.41765285649671013, 0.5173550719005751], Any[0.25035305002619035, 0.04570457124043026], Any[0.040289547208309795, 0.7701179787951304]],"type" => "scatter")],"legend" => Dict("data" => ["Series1", "Blue Series"])), 800, 600)

# %%
ec=EChart("bar",["A","B","C","D","E"],[100,130,80,50,60])
series!(ec,"bar",["A","B","C","D","E"],[120,40,70,50,80])
series!(ec,"line",["A","B","C","D","E"],[50,110,60,20,70])
ec["title"]=Dict("text"=>"Multi Series")
ec
# Out:
# EChart("Dm425RPhMG", Dict{String,Any}("xAxis" => Dict{Any,Any}[Dict("type" => "category")],"yAxis" => Dict{Any,Any}[Dict("type" => "value")],"title" => Dict("text" => "Multi Series"),"series" => Any[Dict{String,Any}("name" => "Series1","data" => Any[Any["A", 100], Any["B", 130], Any["C", 80], Any["D", 50], Any["E", 60]],"type" => "bar"), Dict{String,Any}("name" => "Series2","data" => Any[Any["A", 120], Any["B", 40], Any["C", 70], Any["D", 50], Any["E", 80]],"type" => "bar"), Dict{String,Any}("name" => "Series3","data" => Any[Any["A", 50], Any["B", 110], Any["C", 60], Any["D", 20], Any["E", 70]],"type" => "line")],"legend" => Dict("data" => ["Series1", "Series2", "Series3"])), 800, 600)
